# %% [markdown]
# # Linear regression

# %% [markdown]
# Roksana Cieśla

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model

# %%
import os
path = os.getcwd() + '/ex1data1.txt'
data = pd.read_csv(path, header=None, names=['Population', 'Profit'])

# %% [markdown]
# ## Linear regression with one variable

# %% [markdown]
# <b>Ex. 1.</b> Use the head and describe function to examine the data and display few columns.

# %%
data.head()
# Out:
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
data.describe()
# Out:
#        Population     Profit
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000

# %% [markdown]
# <b>Ex. 2.</b> Extract data from pandas structure to new variables of ndarray type

# %%
x = data.values[:, 0]
y = data.values[:, 1]

# %% [markdown]
# and plot the data, where: x - population, y - profit

# %%
plt.scatter(x, y)
plt.title("Data plot")
plt.ylabel("Profit")
plt.xlabel("Population")
# Out:
# Text(0.5, 0, 'Population')

# %% [markdown]
# <b>Ex. 3.</b> In order to make the cost function work (intercept value θ0 has to be multiplied by 1) we need to insert a column of ones at the top of x.

# %%
data.insert(0, '1s', [1]*data.shape[0])
data.head()
# Out:
#    1s  Population   Profit
# 0   1      6.1101  17.5920
# 1   1      5.5277   9.1302
# 2   1      8.5186  13.6620
# 3   1      7.0032  11.8540
# 4   1      5.8598   6.8233

# %% [markdown]
# <b>Ex. 4.</b> We need to separate our data into independent variables X and our dependent variable y. We also need to initialise parameter θ.

# %%
X = np.stack([np.ones(x.shape, dtype=np.float32), x], axis=0)
y.shape = [1, y.shape[0]]
theta = np.zeros((X.shape[0], 1), dtype=np.float32)

# %% [markdown]
# <b>Ex. 5.</b> The cost function evaluates the quality of our model by calculating the error between our model’s prediction for a data point, using the model parameters, and the actual data point. Please write the cost function based on X,y and parameter θ.

# %%
def computeCost(X, y, theta):
    f = theta.transpose() @ X
    m = y.shape[1]
    J = 1 / (2 * m) * np.sum(np.square(f - y)) 
    return J

# %% [markdown]
# <b>Ex. 6</b> Test the cost function with (θ=0).

# %%
computeCost(X, y, theta)
# Out:
# 32.072733877455676

# %% [markdown]
# <b>Ex. 7.</b> Please implement the gradient descent algorithm

# %%
def simple_gradient(X, y, theta, alpha, it):
    theta = np.float64(theta)
    cost = []
    m = X.shape[1]
    for i in range(it):
        theta = (theta - alpha * (np.transpose((np.transpose(theta)@X-y)@X.T))/m)
        cost.append(computeCost(X, y, theta))
        
    return theta, cost

# %% [markdown]
# <b>Ex. 8.</b> Please calculate the optimal parameters for the dataset.

# %% [markdown]
# <b>Ex. 9.</b> Please calculate the cost function for the given θ (Ex.8).

# %% [markdown]
# <b>Ex. 10.</b> Plot the regression function and our dataset.

# %%
alpha = 0.01
it = 1000
theta1, cost = simple_gradient(X, y, theta, alpha, it)
theta1
# Out:
# array([[-3.24140214],
#        [ 1.1272942 ]])

# %%
x_val = np.arange(5,23)
a = theta1[1]
b = theta1[0]

# %%
plt.scatter(x, y, label="Training data")
plt.plot(x_val, a * x_val + b, 'r', label="Linear regression")
plt.ylabel("Profit")
plt.xlabel("Population")
plt.legend(loc="best")

# %% [markdown]
# <b>Ex. 11</b> Plot the relationship between the cost function and number of iterations

# %%
x3 = np.arange(0,it)
plt.plot(x3, cost, label="cost")
plt.xlabel('Iteration number')
plt.ylabel('Cost function value')
plt.legend(loc="best")

# %% [markdown]
# ## Linear regression with multiple variables

# %%
path = os.getcwd() + '/ex1data2.txt'
data2 = pd.read_csv(path, header=None, names=['Size', 'Bedrooms', 'Price'])
data2.head()
# Out:
#    Size  Bedrooms   Price
# 0  2104         3  399900
# 1  1600         3  329900
# 2  2400         3  369000
# 3  1416         2  232000
# 4  3000         4  539900

# %%
data2.describe()
# Out:
#               Size   Bedrooms          Price
# count    47.000000  47.000000      47.000000
# mean   2000.680851   3.170213  340412.659574
# std     794.702354   0.760982  125039.899586
# min     852.000000   1.000000  169900.000000
# 25%    1432.000000   3.000000  249900.000000
# 50%    1888.000000   3.000000  299900.000000
# 75%    2269.000000   4.000000  384450.000000
# max    4478.000000   5.000000  699900.000000

# %%
x1 = data2.values[:,0]
x2 = data2.values[:,1]
y = data2.values[:,2]

# %% [markdown]
# <b>Ex. 1.</b> Notice that the scale of the values for each variable is vastly different. A house will typically have 2-5 bedrooms but may have anywhere from hundreds to thousands of square feet. To fix this, we need to do something called “feature normalization”. One way to do this is by subtracting from each value in a feature the mean of that feature, and then dividing by the standard deviation

# %%
def feature_normalisation_col(col):
    col_norm = []
    for i in range(len(col)):
        col_norm.append((col[i]-np.mean(col))/np.std(col))
    return np.array(col_norm)

# %%
def feature_normalisation(data):
    for column in data:
        data[column] = (data[column] - data[column].mean()) / data[column].std()

# %% [markdown]
# <b>Ex. 2.</b> Please perform steps 3-11 from the previous task by using the same functions.

# %%
figure, ax = plt.subplots(1, 2, figsize=(17,10))
ax[0].scatter(x1, y)
ax[0].set_title("First variable")
ax[0].set_ylabel("Size of the house")
ax[0].set_xlabel("Price of the house")
ax[1].scatter(x2, y)
ax[1].set_title("Second variable")
ax[1].set_ylabel("Size of the house")
ax[1].set_xlabel("Price of the house")
# Out:
# Text(0.5, 0, 'Price of the house')

# %%
plt.figure(figsize=(8,8))
ax = plt.axes(projection ='3d') 
ax.scatter(x1, x2, y)

# %% [markdown]
# Feature normalisation:

# %%
feature_normalisation(data2)

# %%
x1_norm = data2.values[:,0]
x2_norm = data2.values[:,1]
y_norm = data2.values[:,2]

# %%
data2.insert(0, '1s', [1] * data2.shape[0])
data2.head()
# Out:
#    1s      Size  Bedrooms     Price
# 0   1  0.130010 -0.223675  0.475747
# 1   1 -0.504190 -0.223675 -0.084074
# 2   1  0.502476 -0.223675  0.228626
# 3   1 -0.735723 -1.537767 -0.867025
# 4   1  1.257476  1.090417  1.595389

# %%
plt.figure(figsize=(8,8))
ax = plt.axes(projection ='3d') 
ax.scatter(data2.Size, data2.Bedrooms, data2.Price)

# %%
X = np.stack([np.ones(x1.shape, dtype=np.float64), x1_norm,x2_norm], axis=0)
y_norm.shape = [1, y_norm.shape[0]]
theta2 = np.zeros((X.shape[0], 1), dtype=np.float64)

# %%
computeCost(X, y_norm, theta2)
# Out:
# 0.4893617021276596

# %%
alpha = 0.01
it = 1000
theta2, cost = simple_gradient(X, y_norm, theta2, alpha, it)
theta2
# Out:
# array([[-1.02488939e-16],
#        [ 8.78503652e-01],
#        [-4.69166570e-02]])

# %%
x3d = np.arange(-3, 3)
y3d = np.arange(-3, 3)

plt.figure(figsize=(8,8))
ax = plt.axes(projection ='3d')  
ax.scatter(data2.Size, data2.Bedrooms, data2.Price)
ax.plot(x3d, y3d, theta2[0] + theta2[1] * x3d + theta2[2] * y3d, 'r')

# %%
plt.figure()
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.plot(range(len(cost)), cost)
plt.show()

# %% [markdown]
# ## Linear regression - Python packages

# %% [markdown]
# One variable

# %%
import sklearn.linear_model as sklm
import sklearn.model_selection as skms
path = os.getcwd() + '/ex1data1.txt'
data = pd.read_csv(path, header=None, names=['Population', 'Profit'])
 
x = data.values[:,0]
y = data.values[:,1]

X_train,X_test,y_train,y_test = skms.train_test_split(x,y,test_size = 0.3)
regr = sklm.LinearRegression(fit_intercept=True,copy_X = True ).fit(X_train[:,None],y_train)
Y_predicted = regr.predict(X_test [:,None])
 
# Regression coefficients (theta)
print('Coefficients: \n', regr.coef_)
 
#  Residual sum of squares error
error = np.mean((Y_predicted - y_test) ** 2)
print("Residual sum of squares: {}".format(error))
# Out:
# Coefficients:
#  [1.13512788]
# Residual sum of squares: 5.8808412275726445

# %%
figure, ax = plt.subplots(1, 2, figsize=(15,8))
ax[0].scatter(x, y, label='Training data')
ax[0].plot(x_val, a * x_val + b, 'r', label="Linear regression")
ax[0].set_title("Implementation")
ax[0].legend()
ax[1].scatter(x, y, label='Training data')
ax[1].plot(X_test,Y_predicted,'r',label='Linear regression')
ax[1].set_xlabel("Population")
ax[1].set_ylabel("Profit")
ax[1].set_title("Scikit learn")
ax[1].legend()
plt.show()

# %% [markdown]
# Two variables

# %%
X = np.transpose(np.array([x1_norm,x2_norm]))
X_train,X_test,y_train,y_test = skms.train_test_split(X,y_norm.transpose(),test_size = 0.3)
regr = sklm.LinearRegression(fit_intercept=True,copy_X = True ).fit(X_train,y_train)
Y_predicted = regr.predict(X_test)
 
# Regression coefficients (theta)
print('Coefficients: \n', regr.coef_)
 
#  Residual sum of squares error
error = np.mean((Y_predicted - y_test) ** 2)
print("Residual sum of squares: {}".format(error))
# Out:
# Coefficients:
#  [[ 0.8324549  -0.04347638]]
# Residual sum of squares: 0.19756225238261665

# %%
x3d = np.arange(-3, 3)
y3d = np.arange(-3, 3)

xx1, xx2 = np.meshgrid(x3d, y3d)
model_viz = np.array([xx1.flatten(), xx2.flatten()]).T

ols = sklm.LinearRegression()
model = ols.fit(X, y_norm.transpose())
predicted = model.predict(model_viz)

fig = plt.figure(figsize=(12, 6))
ax1 = fig.add_subplot(121, projection='3d')
ax2 = fig.add_subplot(122, projection='3d')

ax1.scatter(data2.Size, data2.Bedrooms, data2.Price, label='Training data')
ax1.plot(x3d, y3d, theta2[0] + theta2[1] * x3d + theta2[2] * y3d, 'r', label="Linear regression")
ax1.set_title("Implementation")
ax1.legend()
ax2.scatter(data2.Size, data2.Bedrooms, data2.Price, label='Training data')
ax2.scatter(xx1.flatten(), xx2.flatten(),predicted,edgecolor='r', s=20, label='Linear regression')
ax2.set_title("Scikit learn")
ax2.legend()
plt.show()
